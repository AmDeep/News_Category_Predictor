# 7625            0.000000       0.063830        0.085106        0.148936
# 7626            0.016854       0.073034        0.056180        0.129213
# 7627            0.000000      -0.028571        0.028571        0.000000
#
#        Section
# 0     SECTION3
# 1     SECTION0
# 2     SECTION3
# 3     SECTION1
# 4     SECTION3
# 5     SECTION1
# 6     SECTION3
# 7     SECTION3
# 8     SECTION2
# 9     SECTION2
# 10    SECTION1
# 11    SECTION3
# 12    SECTION1
# 13    SECTION1
# 14    SECTION3
# 15    SECTION1
# 16    SECTION1
# 17    SECTION3
# 18    SECTION2
# 19    SECTION1
# 20    SECTION1
# 21    SECTION2
# 22    SECTION3
# 23    SECTION1
# 24    SECTION0
# 25    SECTION1
# 26    SECTION0
# 27    SECTION0
# 28    SECTION0
# 29    SECTION2
# ...        ...
# 7598  SECTION0
# 7599  SECTION1
# 7600  SECTION3
# 7601  SECTION1
# 7602  SECTION0
# 7603  SECTION3
# 7604  SECTION2
# 7605  SECTION1
# 7606  SECTION0
# 7607  SECTION3
# 7608  SECTION1
# 7609  SECTION1
# 7610  SECTION1
# 7611  SECTION2
# 7612  SECTION2
# 7613  SECTION0
# 7614  SECTION3
# 7615  SECTION1
# 7616  SECTION3
# 7617  SECTION1
# 7618  SECTION1
# 7619  SECTION0
# 7620  SECTION2
# 7621  SECTION1
# 7622  SECTION1
# 7623  SECTION0
# 7624  SECTION2
# 7625  SECTION1
# 7626  SECTION0
# 7627  SECTION2
#
# [7628 rows x 15 columns]

# %%
X=DT.drop(columns='Section')
y=DT['Section']

# %%
# Import LabelEncoder
from sklearn import preprocessing
#creating labelEncoder
le = preprocessing.LabelEncoder()

# %%
section_encoded=le.fit_transform(y)

# %%
WordCount_encoded=le.fit_transform(DT['WordCount'])
label=le.fit_transform(DT['SentimentGI'])

# %%
features=X

# %%
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6) # 70% training and 30% test

# %%
#Import knearest neighbors Classifier model
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)

#Train the model using the training sets
knn.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = knn.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# ('Accuracy:', 0.42167358531789384)

# %%
#Import knearest neighbors Classifier model
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=15,algorithm='brute')

#Train the model using the training sets
knn.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = knn.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# ('Accuracy:', 0.43740441337120384)

# %%
#Import knearest neighbors Classifier model
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=17,algorithm='kd_tree')

#Train the model using the training sets
knn.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = knn.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# ('Accuracy:', 0.44024470176971814)

# %%
# Euclidean Distance Caculator
def dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
# Getting the values and plotting it
f1 = X['WordCount']
f2 = X['SentimentyGI']
X = np.array(list(zip(f1, f2)))
plt.scatter(f1, f2, c='black', s=7)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-da417dd5061d> in <module>()
#       1 # Getting the values and plotting it
# ----> 2 f1 = X['WordCount']
#       3 f2 = X['SentimentyGI']
#       4 X = np.array(list(zip(f1, f2)))
#       5 plt.scatter(f1, f2, c='black', s=7)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# Number of clusters
k = 17
# X coordinates of random centroids
C_x = np.random.randint(0, 5, size=k)
# Y coordinates of random centroids
C_y = np.random.randint(0, 5, size=k)
C = np.array(list(zip(C_x, C_y)), dtype=np.float32)
print(C)
# Out:
# [[3. 4.]
#  [2. 0.]
#  [2. 3.]
#  [0. 3.]
#  [1. 0.]
#  [0. 3.]
#  [1. 2.]
#  [4. 1.]
#  [4. 0.]
#  [3. 0.]
#  [2. 1.]
#  [1. 1.]
#  [1. 4.]
#  [3. 1.]
#  [0. 0.]
#  [2. 4.]
#  [3. 4.]]

# %%
# Plotting along with the Centroids
plt.scatter(f1, f2, c='#050505', s=7)
plt.scatter(C_x, C_y, marker='*', s=200, c='g')
